# %% [markdown]
# # <center>Inroduction to Image </center>

# %% [markdown]
# <center><img src="https://learn.g2crowd.com/hubfs/what%20is%20RGB.png" height=200 width:500/></center>

# %% [markdown]
# CMYK is the color mode intended for printing with ink, such as business card designs.
#
# RGB is the color mode intended for screen displays.

# %%
# Images
# 1. 3 channel images (these images have 3 color channel -- RED GREEN BLUE)
# These 3 color channel can produce any color of choice.

# 2. 1 channel image (it is made up of only on echannel)
# The color in the images are between the shade of white...

# 3. 4 channel images (3 channel images with a transparency layer)
# Example: Water mark images

# %%
# Color -- RGB can make any color.

# %%
# Intensity - (0, 255)

# %%
# For humans, image is a beautiful way of capturing monents.
# But for machines it is nothing but a simple MATRIX of NUMBERS.

# %%
# How to read images:

# We have multiple options:
# 1. OpenCV
# 2. Pillow
# 3. matplotlib
# 4. skimage

# %% [markdown]
# OpenCV Documentation: https://docs.opencv.org/5.x/

# %%
# Download a image on colab
# !wget <image_url> -- this is a linux based command.

# %%
# For windows:
# !python -m wget https://static.vecteezy.com/packs/media/photos/term-bg-1-c9813571.jpg -o pic_1.jpg
# Out:
# Traceback (most recent call last):
#   File "d:\Users\SHAYAN\Anaconda\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "d:\Users\SHAYAN\Anaconda\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "d:\Users\SHAYAN\Anaconda\lib\site-packages\wget.py", line 568, in <module>
#     filename = download(args[0], out=options.output)
#   File "d:\Users\SHAYAN\Anaconda\lib\site-packages\wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#   File "d:\Users\SHAYAN\Anaconda\lib\urllib\request.py", line 239, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "d:\Users\SHAYAN\Anaconda\lib\urllib\request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "d:\Users\SHAYAN\Anaconda\lib\urllib\request.py", line 523, in open
#     response = meth(req, response)
# ...

# %%
# %pip install wget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wget

# %%
# !wget https://static.vecteezy.com/packs/media/photos/term-bg-1-c9813571.jpg
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Install Opencv
# !pip show opencv-python
# Out:
# Name: opencv-python
# Version: 4.6.0.66
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/skvark/opencv-python
# Author:
# Author-email:
# License: MIT
# Location: d:\users\shayan\anaconda\lib\site-packages
# Requires: numpy, numpy, numpy
# Required-by:

# %%
#import
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="term_bg.jpg" height=200 width=300/>

# %%
image = cv2.imread("term_bg.jpg")

# %%
type(image)  # NUMPY ARRAY (MATRIX)
# Out:
# numpy.ndarray

# %%
image.shape # 3 Channel image (height=550, width=550, width=3)
# Out:
# (550, 550, 3)

# %%
# Import Matplotlib to show image
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
# OpenCV does not read mage in RGB format. It read it in BGR Format.
# So, we need to convert the colour channel (cv2.COLOR_BGR2RGB) to get the exact color image.

# %%
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image2.shape
# Out:
# (550, 550, 3)

# %%
plt.imshow(image2)  # Now, the color of image is in the original order.

# %%
import numpy as np

# %%
a = np.zeros(300).reshape(10,10,3)

# %%
a.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(a)

# %%
a = np.zeros(300).reshape(10,10,3)

# %%
a[:,:,0]=255

# %%
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a[:,:,1]=1
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a[1,1,:]
# Out:
# array([255.,   1.,   0.])

# %%
a = np.zeros(300).reshape(10,10,3)
a[:,:,0]=5.0
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a = np.zeros(300).reshape(10,10,3)
a[:,:,0]=255.0
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Make only Green Color
a = np.zeros(300).reshape(10,10,3)
a[:,:,1]=255.0
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Put only Blue Color
a = np.zeros(300).reshape(10,10,3)
a[:,:,2]=255.0
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(image2)

# %%
# Now, See only Green color
plt.imshow(image2[:,:,1])

# %%
# Now, See only Blue color
plt.imshow(image2[:,:,2])

# %%
# Now, See only Red color
plt.imshow(image2[:,:,0])

# %%
# Every image is just a matrix made up of numbers from (0 to 255)
image2[:,:,2]
# Out:
# array([[ 3,  3,  3, ...,  1,  0,  0],
#        [ 3,  2,  2, ...,  1,  0,  0],
#        [ 2,  2,  2, ...,  1,  0,  0],
#        ...,
#        [ 2,  2,  1, ..., 40, 40, 40],
#        [ 2,  2,  1, ..., 40, 40, 40],
#        [ 3,  2,  1, ..., 40, 40, 41]], dtype=uint8)

# %%
# shape of image
image2.shape
# Out:
# (550, 550, 3)

# %%
# Resize the image
image3 = cv2.resize(image2, (400,400))

# %%
# Now check shape of image
image3.shape
# Out:
# (400, 400, 3)

# %%
plt.subplot(1,2,1)
plt.imshow(image3)
plt.subplot(1,2,2)
plt.imshow(image2)

# %%
#Install pillow package
# !pip show pillow
# Out:
# Name: Pillow
# Version: 9.0.1
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.org
# Author: Alex Clark (PIL Fork Author)
# Author-email: aclark@python-pillow.org
# License: HPND
# Location: d:\users\shayan\anaconda\lib\site-packages
# Requires:
# Required-by: scikit-image, matplotlib, imageio, datashader, bokeh

# %%
image_ = cv2.imread("588px-RGB_color_model.svg.png")
# plt.imshow(image_)

# %%
from PIL import Image

# %%
Image.open("588px-RGB_color_model.svg.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=588x600 at 0x1F6D9511FD0>

# %% [markdown]
# <img src="https://miro.medium.com/max/1186/1*25fn_MCjsrPDPjT6zkhB_A.png"/>

# %%
# OpenCV

# 1. Read an image
# 2. Check the shape
# 3. Change color channel format
# 4. Resize image

# %% [markdown]
# ### Single Channel Image

# %%
gray = cv2.imread("gray.jpeg")

# %%
gray.shape  #MAke it single-channel image
# Out:
# (1204, 1880, 3)

# %%
# MAke it a single channel image
gray = cv2.imread("gray.jpeg",0)

# %%
gray.shape
# Out:
# (1204, 1880)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap="gray")

# %%
image5 = cv2.cvtColor(image2, cv2.COLOR_RGB2GRAY)
plt.imshow(image5, cmap='gray')

# %%
image5.shape
# Out:
# (550, 550)

# %%
rgb = cv2.imread("588px-RGB_color_model.svg.png")
rgb = cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
plt.imshow(rgb[:,:,0])

# %%
# Focus only on R-Channel
plt.imshow(rgb[:,:,0], cmap='gray')

# %%
# Focus only on B-Channel
plt.imshow(rgb[:,:,2], cmap='gray')

# %% [markdown]
# END
